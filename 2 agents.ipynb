# %%
# %pip install -U autogen-agentchat autogen-ext[openai]
# Out:
# ...
#   Using cached autogen_ext-0.7.5-py3-none-any.whl.metadata (7.3 kB)
# ...
# Using cached autogen_ext-0.7.5-py3-none-any.whl (331 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# C:\Anaconda3\python.exe
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %%
import autogen
autogen.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import autogen
#       2 autogen.__version__
#
# ModuleNotFoundError: No module named 'autogen'

# %%
# !conda run -n autogen311 python -m ipykernel install --user --name autogen311 --display-name "Python 3.11 (AutoGen)"
# Out:
# Installed kernelspec autogen311 in C:\Users\achu3\AppData\Roaming\jupyter\kernels\autogen311
